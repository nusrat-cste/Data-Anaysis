# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
def Plot_axisXYZ(list_timeStamp,x,y,z):
    fig, axs = plt.subplots(3, 1, sharex=True)
    # Remove horizontal space between axes
    fig.subplots_adjust(hspace=0)

    # Plot each graph, and manually set the y tick values

    axs[0].plot(list_timeStamp, x)
    axs[0].legend(['Ax'])

    # axs[0].set_yticks(np.arange(-0.9, 1.0, 0.4))
    # axs[0].set_ylim(-1, 1)

    axs[1].plot(list_timeStamp, y)
    axs[1].legend(['Ay'])

    # axs[1].set_yticks(np.arange(0.1, 1.0, 0.2))
    # axs[1].set_ylim(0, 1)

    axs[2].plot(list_timeStamp, z)
    axs[2].legend(['Az'])

    # axs[2].set_yticks(np.arange(-0.9, 1.0, 0.4))
    # axs[2].set_ylim(-1, 1)
   
    plt.show()

def Plot_Sensors_impact(list_timeStamp2,A,B,C,D, impact):
    fig, axs = plt.subplots(5, 1, sharex=True)
    # Remove horizontal space between axes
    fig.subplots_adjust(hspace=0)

    # Plot each graph, and manually set the y tick values

    axs[0].plot(list_timeStamp2, A)
    axs[0].legend(['A'])

    # axs[0].set_yticks(np.arange(-0.9, 1.0, 0.4))
    # axs[0].set_ylim(-1, 1)

    axs[1].plot(list_timeStamp2, B)
    axs[1].legend(['B'])

    # axs[1].set_yticks(np.arange(0.1, 1.0, 0.2))
    # axs[1].set_ylim(0, 1)

    axs[2].plot(list_timeStamp2, C)
    axs[2].legend(['C'])

    # axs[2].set_yticks(np.arange(-0.9, 1.0, 0.4))
    # axs[2].set_ylim(-1, 1)
    axs[3].plot(list_timeStamp2, D)
    axs[3].legend(['D'])

    axs[4].plot(list_timeStamp2, impact)
    axs[4].legend(['impact'])
   
    plt.show()

    
    
fh = open('F:/2-2/research/nusrat_2_min_walk.json')
data = json.load(fh)
list_timeStamp = []
list_Ax = []
list_Ay = []
list_Az = []
list_Bx = []
list_By = []
list_Bz = []
list_Cx = []
list_Cy = []
list_Cz = []


for item in data['Data']['6X1CSV']['AccelerometerData']:
    list_timeStamp.append(item)
    list_Ax.append(data['Data']['6X1CSV']['AccelerometerData'][item]['Ax'])
    list_Ay.append(data['Data']['6X1CSV']['AccelerometerData'][item]['Ay'])
    list_Az.append(data['Data']['6X1CSV']['AccelerometerData'][item]['Az'])
    list_Bx.append(data['Data']['6X1CSV']['AccelerometerData'][item]['Bx'])
    list_By.append(data['Data']['6X1CSV']['AccelerometerData'][item]['By'])
    list_Bz.append(data['Data']['6X1CSV']['AccelerometerData'][item]['Bz'])
    list_Cx.append(data['Data']['6X1CSV']['AccelerometerData'][item]['Cx'])
    list_Cy.append(data['Data']['6X1CSV']['AccelerometerData'][item]['Cy'])
    list_Cz.append(data['Data']['6X1CSV']['AccelerometerData'][item]['Cz'])


# Plot_axisXYZ(list_timeStamp,list_Ax,list_Ay,list_Az)
# Plot_axisXYZ(list_timeStamp,list_Bx,list_By,list_Bz)
# Plot_axisXYZ(list_timeStamp,list_Cx,list_Cy,list_Cz)


list_timeStamp2 = []
list_A= []
list_B= []
list_C= []
list_D= []
list_impact = []
for item in data['Data']['6X1CSV']['SensorReading']:
    list_timeStamp2.append(item)
    if(data['Data']['6X1CSV']['SensorReading'][item]['A']):
        print(data['Data']['6X1CSV']['SensorReading'][item]['A'])
        list_A.append('1')
    else:
        list_A.append('0')
    if(data['Data']['6X1CSV']['SensorReading'][item]['B']):
        list_B.append('1')
    else:
        list_B.append('0')
    if(data['Data']['6X1CSV']['SensorReading'][item]['C']):
        list_C.append('1')
    else:
        list_C.append('0')
    if(data['Data']['6X1CSV']['SensorReading'][item]['D']):
        list_D.append('1')
    else:
        list_D.append('0')
    list_impact.append(data['Data']['6X1CSV']['SensorReading'][item]['impact'])

Plot_Sensors_impact(list_timeStamp2,list_A,list_B,list_C,list_D, list_impact)
Plot_axisXYZ(list_timeStamp,list_Ax,list_Ay,list_Az)
Plot_axisXYZ(list_timeStamp,list_Bx,list_By,list_Bz)
Plot_axisXYZ(list_timeStamp,list_Cx,list_Cy,list_Cz)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
